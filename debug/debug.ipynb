# %%
import pprint
from ollama import chat
from fastmcp import Client
from fastmcp.client.transports import SSETransport

# %%
transport = SSETransport(url="http://localhost:8082/sse")
async with Client(transport) as client:
    tools = await client.list_tools()
    ollama_tools = []
    for tool in tools:
        tool_dict = tool.model_dump()

        ollama_tools.append({
            "type": "function",
            "function": {
                "name": tool_dict["name"],
                "description": tool_dict["description"],
                "parameters": tool_dict["inputSchema"]
            }
        })

# %%
content = """
당신은 최신 정보를 찾는 AI 리서처입니다.

1. 사용자의 질문을 의미 있는 키워드 또는 주제별로 분해하세요.
2. 각 키워드/주제마다 3~5개의 웹검색 쿼리를 생성하세요.
3. 각 쿼리에 대해 info_search_web(또는 search_web) 툴을 호출해 최신 정보를 수집하세요.
4. 수집한 정보를 통합하여, 신뢰할 수 있는 출처(URL)와 함께 요약 보고서를 작성하세요.
5. 요약은 명확하고, 사실 기반이며, 출처를 반드시 포함하세요.

예시 입력:
"2024년 미국 대선 후보의 주요 공약과 최근 AI 규제 동향을 알려줘"

예시 작업 흐름:
- [1단계] 쿼리 분해: ["2024년 미국 대선 후보 주요 공약", "2024년 미국 AI 규제 동향"]
- [2단계] 각 항목별 검색 쿼리 생성
- [3단계] 각 쿼리로 info_search_web 툴 콜
- [4단계] 결과 통합 및 출처 포함 요약

각 툴 콜의 파라미터 예시:
{
  "query": "2024 US presidential candidates main pledges",
  "date_range": "past_month"
}

{
  "query": "2024 US AI regulation trends",
  "date_range": "past_month"
}
"""

messages = [
    {"role": "system", "content": content},
    {"role": "user", "content": "주술회전, 나루토, 원피스, 김문수 가 뭐야? /no_think"}
]

print("STEP 1: Call Tools")
response = chat(
    model="qwen3:8b",
    messages=messages,
    tools=ollama_tools,
    keep_alive = -1
)

if "tool_calls" in response["message"]:
    pprint.pprint(response["message"]["tool_calls"])
else:
    print("툴 없음")
    pprint.pprint(response["message"]["content"])
# Out:
# STEP 1: Call Tools
# [ToolCall(function=Function(name='web_search', arguments={'query': '주술회전 나루토 원피스 김문수 뜻'})),
#  ToolCall(function=Function(name='web_search', arguments={'query': '주술회전 나루토 원피스 김문수 정의'})),
#  ToolCall(function=Function(name='web_search', arguments={'query': '주술회전 나루토 원피스 김문수 설명'}))]

# %%
if "tool_calls" in response["message"]:
    tool_calls = response["message"]["tool_calls"]
    for tool_call in tool_calls:
        fn = tool_call["function"]
        async with Client(transport) as mcp_client:
            result = await mcp_client.call_tool(
                name = fn["name"], 
                arguments = fn["arguments"]
            )

        messages.append({
                    "role": "tool",
                    "name": fn["name"],
                    "content": result[0].text + " /no_think"
                })
    
print("STEP 2: Add Tool Result")
pprint.pprint(messages)
print()
# Out:
# STEP 2: Add Tool Result
# [{'content': 'You are a helpful assistant. Use the toolㄴㄴ for questions.',
#   'role': 'system'},
#  {'content': '주술회전이 뭐야? /no_think', 'role': 'user'},
#  {'content': '주술회전\n'
#              '-\n'
#              '나무위키\n'
#              '최근\n'
#              '변경최근\n'
#              '토론특수\n'
#              '기능\n'
#              '주술회전\n'
#              '최근\n'
#              '수정\n'
#              '시각:\n'
#              '2025-05-05\n'
#              '07:26:07138편집\n'
#              '요청편집\n'
#              '요청편집\n'
#              '권한이\n'
#              '부족합니다.\n'
#              '로그인된\n'
#              '사용자(이)여야\n'
#              '합니다.\n'
#              '해당\n'
#              '문서의\n'
#              'ACL\n'
#              '탭을\n'
#              '확인하시기\n'
#              '바랍니다.\n'
#              '편집\n'
#              '권한이\n'
#              '부족한\n'
#              '경우\n'
#              '아래의\n'
#              "'편집\n"
#              "요청'\n"
#              '버튼으로\n'
#              '편집\n'
#              '요청을\n'
#              '생성할\n'
#              '수\n'
#              '있습니다.\n'
#              '[편집\n'
#              '요청\n'
#              '도움말]편집\n'
#              '요청닫기토론역사분류주술회전일본\n'
#              '만화/목록발매\n'
#              '현황\n'
#              '(단편\n'
#              '·\n'
#              '팬북\n'
#              '·\n'
#              '소설)\n'
#              '|\n'
#              '회차\n'
#              '목록\n'
#              '등장인물\n'
#              '(주술고전\n'
#              '·\n'
#              '주령)\n'
#              '|\n'
#              '설정\n'
#              '(주력\n'
#              '·\n'
#              '술식\n'
#              '·\n'
#              '영역\n'
#              '전개\n'
#              '·\n'
#              '종족)줄거리\n'
#              '(회옥·옥절\n'
#              '·\n'
#              '백귀야행\n'
#              '·\n'
#              '시부야\n'
#              '사변\n'
#              '·\n'
#              '사멸회유\n'
#              '·\n'
#              '인외마경\n'
#              '신주쿠\n'
#              '결전)비판\n'
#              '및\n'
#              '논란\n'
#              '(캐릭터)\n'
#              '|\n'
#              '갤러리애니메이션\n'
#              '(TVA\n'
#              '1기\n'
#              '·\n'
#              '극장판\n'
#              '·\n'
#              'TVA\n'
#              '2기\n'
#              '(극장판\n'
#              '총집편\n'
#              '회옥·옥절)\n'
#              '·\n'
#              'TVA\n'
#              '3기\n'
#              '·\n'
#              '음악\n'
#              '·\n'
#              '평가)게임\n'
#              '(팬텀\n'
#              '퍼레이드\n'
#              '·\n'
#              '전화향명)기타\n'
#              '(인기투표)\n'
#              '·\n'
#              '(존재하지\n'
#              '않는\n'
#              '기억)주술회전呪術廻戦Jujutsu\n'
#              'Kaisen장르퇴마,\n'
#              '어반\n'
#              '판타지,\n'
#              '다크\n'
#              '판타지작가아쿠타미\n'
#              '게게출판사\n'
#              '슈에이샤\n'
#              '서울미디어코믹스연재처주간\n'
#              '소년\n'
#              '점프레이블\n'
#              '점프\n'
#              '코믹스\n'
#              '아이큐\n'
#              '점프\n'
#              '코믹스연재\n'
#              '기간2018년\n'
#              '14호\n'
#              '~\n'
#              '2024년\n'
#              '44호[1]단행본\n'
#              '권수\n'
#              '30권\n'
#              '(2024.\n'
#              '12.\n'
#              '25.\n'
#              '完)\n'
#              '29권\n'
#              '(2025.\n'
#              '4.\n'
#              '30.)\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0'
#              '1.\n'
#              '개요2.\n'
#              '줄거리2.1.\n'
#              '회차\n'
#              '목록3.\n'
#              '발매\n'
#              '현황3.1.\n'
#              '표지\n'
#              '인물\n'
#              '일람4.\n'
#              '특징5.\n'
#              '등장인물6.\n'
#              '설정7.\n'
#              '인기7.1.\n'
#              '누계\n'
#              '발행\n'
#              '부수8.\n'
#              '평가8.1.\n'
#              '비판\n'
#              '및\n'
#              '논란9.\n'
#              '미디어\n'
#              '믹스9.1.\n'
#              '애니메이션9.1.1.\n'
#              '컴플리트\n'
#              '북9.2.\n'
#              '팬북9.3.\n'
#              '소설9.4.\n'
#              '게임9.4.1.\n'
#              '주술회전\n'
#              '팬텀\n'
#              '퍼레이드9.4.2.\n'
#              '주술회전\n'
#              '전화향명9.5.\n'
#              '콜라보레이션10.\n'
#              '기타\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0'
#              '1.\n'
#              '개요[편집]\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0'
#              '일본의\n'
#              '어반\n'
#              '판타지·배틀물\n'
#              '만화이자\n'
#              '도쿄\n'
#              '도립\n'
#              '주술\n'
#              '고등전문학교의\n'
#              '후속작.\n'
#              '작가는\n'
#              '아쿠타미\n'
#              '게게.제목의\n'
#              "'회전'은\n"
#              '빙글빙글\n'
#              '돈다는\n'
#              '뜻의\n'
#              '회전(回轉)이나\n'
#              '대규모\n'
#              '군대가\n'
#              '서로\n'
#              '맞붙는\n'
#              '회전(會戰)이\n'
#              '아닌\n'
#              '다른\n'
#              '의미의\n'
#              '회전(廻戰)[2]을\n'
#              '사용한다.\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0'
#              '2.\n'
#              '줄거리[편집]\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0'
#              '평범한\n'
#              '소년\n'
#              'VS\n'
#              '저주의\n'
#              '왕\n'
#              '격돌!!햇병아리\n'
#              '주술사들의\n'
#              '뜨거운\n'
#              '반란이\n'
#              '시작된다.경이로운\n'
#              '신체\n'
#              '능력을\n'
#              '가진\n'
#              '고등학생\n'
#              '이타도리\n'
#              '유지는\n'
#              '병상에\n'
#              '누워\n'
#              '있는\n'
#              '할아버지의\n'
#              '병문안을\n'
#              '가는\n'
#              '것이\n'
#              '일과이다.\n'
#              '그러던\n'
#              '어느\n'
#              '날,\n'
#              '학교에\n'
#              '잠들어\n'
#              '있던\n'
#              "'주물(呪物)'의\n"
#              '봉인이\n'
#              '풀리면서\n'
#              '괴물이\n'
#              '나타나고\n'
#              '이타도리는\n'
#              '미처\n'
#              '도망치지\n'
#              '못한\n'
#              '선배를\n'
#              '구하기\n'
#              '위해\n'
#              '학교\n'
#              '건물로\n'
#              '뛰어드는데?!―\n'
#              'yes24\n'
#              '소개\n'
#              '자세한\n'
#              '내용은\n'
#              '주술회전/줄거리\n'
#              '문서를\n'
#              '참고하십시오.\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0'
#              '2.1.\n'
#              '회차\n'
#              '목록[편집]\n'
#              '자세한\n'
#              '내용은\n'
#              '주술회전/회차\n'
#              '목록\n'
#              '문서를\n'
#              '참고하십시오.\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0'
#              '3.\n'
#              '발매\n'
#              '현황[편집]\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0'
#              '0권[3]01권02권03권눈부신\n'
#              '어둠양면\n'
#              '스쿠나주태대천어린\n'
#              '물고기와\n'
#              '역벌\n'
#              '2018년\n'
#              '12월\n'
#              '04일\n'
#              '2019년\n'
#              '04월\n'
#              '25일\n'
#              '2018년\n'
#              '07월\n'
#              '04일\n'
#              '2019년\n'
#              '03월\n'
#              '29일\n'
#              '2018년\n'
#              '09월\n'
#              '04일\n'
#              '2019년\n'
#              '03월\n'
#              '29일\n'
#              '2018년\n'
#              '12월\n'
#              '04일\n'
#              '2019년\n'
#              '04월\n'
#              '30일04권05권06권07권죽여버리겠어교토\n'
#              '자매\n'
#              '학교\n'
#              '교류회흑섬기수뇌동\n'
#              '2019년\n'
#              '03월\n'
#              '04일\n'
#              '2019년\n'
#              '05월\n'
#              '22일\n'
#              '2019년\n'
#              '05월\n'
#              '02일\n'
#              '2019년\n'
#              '07월\n'
#              '15일\n'
#              '2019년\n'
#              '07월\n'
#              '04일\n'
#              '2019년\n'
#              '09월\n'
#              '25일\n'
#              '2019년\n'
#              '10월\n'
#              '04일\n'
#              '2019년\n'
#              '12월\n'
#              '31일08권09권10권11권회옥옥절전야제시부야\n'
#              '사변\n'
#              '-개문-\n'
#              '2020년\n'
#              '01월\n'
#              '04일\n'
#              '2020년\n'
#              '10월\n'
#              '14일\n'
#              '2020년\n'
#              '01월\n'
#              '04일\n'
#              '2020년\n'
#              '11월\n'
#              '13일\n'
#              '2020년\n'
#              '03월\n'
#              '04일\n'
#              '2020년\n'
#              '12월\n'
#              '11일\n'
#              '2020년\n'
#              '06월\n'
#              '04일\n'
#              '2021년\n'
#              '01월\n'
#              '13일12권13권14권15권시부야\n'
#              '사변\n'
#              '-강령-시부야\n'
#              '사변\n'
#              '-벽력-시부야\n'
#              '사변\n'
#              '-이비-시부야\n'
#              '사변\n'
#              '-변신-\n'
#              '2020년\n'
#              '08월\n'
#              '04일\n'
#              '2021년\n'
#              '02월\n'
#              '16일\n'
#              '2020년\n'
#              '10월\n'
#              '02일\n'
#              '2021년\n'
#              '03월\n'
#              '17일\n'
#              '2021년\n'
#              '01월\n'
#              '04일\n'
#              '2021년\n'
#              '04월\n'
#              '15일\n'
#              '2021년\n'
#              '03월\n'
#              '04일\n'
#              '2021년\n'
#              '05월\n'
#              '18일16권17권18권\n'
#              '19권\n'
#              '시부야\n'
#              '사변\n'
#              '-폐문-갈대를\n'
#              '입에\n'
#              '물다열기도쿄\n'
#              '제1콜로니\n'
#              '-화내는\n'
#              '남자-\n'
#              '2021년\n'
#              '06월\n'
#              '04일\n'
#              '2021년\n'
#              '08월\n'
#              '26일\n'
#              '2021년\n'
#              '10월\n'
#              '04일\n'
#              '2021년\n'
#              '11월\n'
#              '30일\n'
#              '2021년\n'
#              '12월\n'
#              '25일\n'
#              '2022년\n'
#              '02월\n'
#              '23일\n'
#              '2022년\n'
#              '04월\n'
#              '04일\n'
#              '2022년\n'
#              '06월\n'
#              '24일20권21권22권\n'
#              '23권\n'
#              '센다이\n'
#              '콜로니\n'
#              '-연회\n'
#              '중반-도쿄\n'
#              '제2콜로니\n'
#              '-호운-사쿠라지마\n'
#              '콜로니\n'
#              '-환생-\n'
#              '별과\n'
#              '기름\n'
#              '2022년\n'
#              '08월\n'
#              '04일\n'
#              '2022년\n'
#              '10월\n'
#              '25일\n'
#              '2022년\n'
#              '12월\n'
#              '02일\n'
#              '2022년\n'
#              '12월\n'
#              '29일\n'
#              '2023년\n'
#              '03월\n'
#              '03일\n'
#              '2023년\n'
#              '05월\n'
#              '29일\n'
#              '2023년\n'
#              '07월\n'
#              '04일\n'
#              '2023년\n'
#              '08월\n'
#              '30일24권25권26권27권주태대천\n'
#              '-재귀-인외마경\n'
#              '신주쿠\n'
#              '결전남쪽으로바보\n'
#              '서바이버!!\n'
#              '2023년\n'
#              '10월\n'
#              '04일\n'
#              '2023년\n'
#              '12월\n'
#              '08일\n'
#              '2024년\n'
#              '01월\n'
#              '04일\n'
#              '2024년\n'
#              '02월\n'
#              '27일\n'
#              '2024년\n'
#              '04월\n'
#              '04일\n'
#              '2024년\n'
#              '06월\n'
#              '21일\n'
#              '2024년\n'
#              '07월\n'
#              '04일\n'
#              '2024년\n'
#              '08월\n'
#              '29일28권29권30권\n'
#              '(完)인외마경\n'
#              '신주쿠\n'
#              '결전\n'
#              '-9점\n'
#              '접바둑-인외마경\n'
#              '신주쿠\n'
#              '결전\n'
#              '-사활-이제부터\n'
#              '2024년\n'
#              '10월\n'
#              '04일\n'
#              '2024년\n'
#              '12월\n'
#              '31일\n'
#              '2024년\n'
#              '12월\n'
#              '25일\n'
#              '2025년\n'
#              '4월\n'
#              '30일\n'
#              '2024년\n'
#              '12월\n'
#              '25일\n'
#              '미정주간\n'
#              '소년\n'
#              '점프에서\n'
#              '2018년\n'
#              '14호부터\n'
#              '2024년\n'
#              '44호까지\n'
#              '연재되었으며\n'
#              '단행본은\n'
#              '점프\n'
#              '코믹스\n'
#              '레이블로\n'
#              '발매된다.정식\n'
#              '한국어판은\n'
#              '서울미디어코믹스를\n'
#              '통해\n'
#              '2019년\n'
#              '3월에\n'
#              '1,\n'
#              '2권을\n'
#              '시작으로\n'
#              '정발이\n'
#              '시작되었다.\n'
#              '번역가는\n'
#              '이정운.\n'
#              '번역의\n'
#              '질은\n'
#              '전반적으로\n'
#              '무난한\n'
#              '편이지만\n'
#              '스쿠나의\n'
#              '말투가\n'
#              '잼민이\n'
#              '같다며\n'
#              '깬다는\n'
#              '의견이\n'
#              '좀\n'
#              '있다.단행본이\n'
#              '발매될\n'
#              '때마다\n'
#              '점프\n'
#              '공식\n'
#              '채널에서\n'
#              '해당\n'
#              '단행본의\n'
#              '내용과\n'
#              '관련된\n'
#              '프로모션\n'
#              '비디오가\n'
#              '공개되는데,\n'
#              '원작\n'
#              '만화\n'
#              '속\n'
#              '장면을\n'
#              '편집해\n'
#              '애니메이션처럼\n'
#              '만들거나\n'
#              '실사\n'
#              '영상에\n'
#              'CG를\n'
#              '넣는\n'
#              '등\n'
#              '퀄리티가\n'
#              '꽤\n'
#              '높은\n'
#              '편.30권으로\n'
#              '완결되며\n'
#              '29권과\n'
#              '함께\n'
#              '2024년\n'
#              '12월\n'
#              '25일에\n'
#              '동시\n'
#              '발매되었다.\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0'
#              '3.1.\n'
#              '표지\n'
#              '인물\n'
#              '일람[편집]\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0'
#              '0권\n'
#              '-\n'
#              '옷코츠\n'
#              '유타,\n'
#              '오리모토\n'
#              '리카1권\n'
#              '-\n'
#              '이타도리\n'
#              '유지2권\n'
#              '-\n'
#              '후시구로\n'
#              '메구미3권\n'
#              '-\n'
#              '쿠기사키\n'
#              '노바라4권\n'
#              '-\n'
#              '고죠\n'
#              '사토루5권\n'
#              '-\n'
#              '토도\n'
#              '아오이,\n'
#              '타카다\n'
#              '노부코6권\n'
#              '-\n'
#              '마히토7권\n'
#              '-\n'
#              '쵸소우[4]8권\n'
#              '-\n'
#              '후시구로\n'
#              '토우지9권\n'
#              '-\n'
#              '게토\n'
#              '스구루10권\n'
#              '-\n'
#              '얼티밋\n'
#              '메카마루11권\n'
#              '-\n'
#              '나나미\n'
#              '켄토12권\n'
#              '-\n'
#              '메이메이13권\n'
#              '-\n'
#              '쿠사카베\n'
#              '아츠야14권\n'
#              '-\n'
#              '료멘스쿠나이타도리\n'
#              '유지15권\n'
#              '-\n'
#              '마히토16권\n'
#              '-\n'
#              '켄자쿠게토\n'
#              '스구루17권\n'
#              '-\n'
#              '젠인\n'
#              '나오야18권\n'
#              '-\n'
#              '하카리\n'
#              '킨지19권\n'
#              '-\n'
#              '히구루마\n'
#              '히로미20권\n'
#              '-\n'
#              '이시고리\n'
#              '류21권\n'
#              '-\n'
#              '카시모\n'
#              '하지메22권\n'
#              '-\n'
#              '젠인\n'
#              '마키\n'
#              '[5]23권\n'
#              '-\n'
#              '츠쿠모\n'
#              '유키24권\n'
#              '-\n'
#              '쿠루스\n'
#              '하나25권\n'
#              '-\n'
#              '료멘스쿠나스포일러26권\n'
#              '-\n'
#              '고죠\n'
#              '사토루27권\n'
#              '-\n'
#              '타카바\n'
#              '후미히코28권\n'
#              '-\n'
#              '옷코츠\n'
#              '유타29권\n'
#              '-\n'
#              '료멘스쿠나30권\n'
#              '-\n'
#              '이타도리\n'
#              '유지\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0'
#              '4.\n'
#              '특징[편집]\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0'
#              '전체적인\n'
#              '설정의\n'
#              '뼈대나\n'
#              '전개의\n'
#              '구성은\n'
#              '마치\n'
#              '왕도적인\n'
#              '소년만화식\n'
#              '스토리처럼\n'
#              '보이다가\n'
#              '갑자기\n'
#              '시부야\n'
#              '사변부터\n'
#              '현실은\n'
#              '시궁창이라는\n'
#              '듯이\n'
#              '꿈도\n'
#              '희망도\n'
#              '없는\n'
#              '결론을\n'
#              '보여주기도\n'
#              '한다.[6]마치\n'
#              '평범한\n'
#              '소년만화인\n'
#              '것처럼\n'
#              '보이다가\n'
#              '결정적인\n'
#              '부분에서\n'
#              '클리셰를\n'
#              '박살내면서\n'
#              '내달리는\n'
#              '전개가\n'
#              '특징이다.\n'
#              '대표적인\n'
#              '예가\n'
#              '바로\n'
#              '"어린\n'
#              '물고기와\n'
#              '역벌"\n'
#              '편인데,\n'
#              '비관적인\n'
#              '현실[7]에\n'
#              '타락해버린\n'
#              '요시노\n'
#              '준페이가\n'
#              '짧은\n'
#              '시간이지만\n'
#              '친해졌던\n'
#              '이타도리\n'
#              '유지의\n'
#              '설득으로\n'
#              '동료로\n'
#              '돌아서는\n'
#              '훈훈한\n'
#              '엔딩...으로\n'
#              '갈\n'
#              '것처럼\n'
#              '보이다가\n'
#              '진짜\n'
#              '악역이\n'
#              '등장하고\n'
#              '그\n'
#              '자리에서\n'
#              '다음\n'
#              '컷에\n'
#              '죽어버린다.\n'
#              '심지어\n'
#              '그냥\n'
#              '죽은\n'
#              '것도\n'
#              '아니고\n'
#              '회생\n'
#              '가능성\n'
#              '0%의\n'
#              '끔살이며,\n'
#              '설상가상\n'
#              '아직\n'
#              '고등학생인\n'
#              '이타도리는\n'
#              '이\n'
#              '에피소드에서\n'
#              '살인[8]을\n'
#              '강요당한다.\n'
#              '2010년대\n'
#              '후반\n'
#              '소년\n'
#              '점프\n'
#              '히트작은\n'
#              '어두운\n'
#              '성향이\n'
#              '강한\n'
#              '편인데\n'
#              '이것도\n'
#              '그\n'
#              '중\n'
#              '하나.이러한\n'
#              '전개의\n'
#              '원인은\n'
#              '작가의\n'
#              '매니악한\n'
#              '성향\n'
#              '때문인데,\n'
#              '주술회전을\n'
#              '연재하기\n'
#              '전\n'
#              '점프에\n'
#              '들고\n'
#              '간\n'
#              '작품의\n'
#              '시안이\n'
#              '"점프스럽지\n'
#              '않다"며\n'
#              '거절당하자\n'
#              '상심이\n'
#              '컸다고\n'
#              '한다.[9]\n'
#              '그러다가\n'
#              '히노마루\n'
#              '스모와\n'
#              '나의\n'
#              '히어로\n'
#              '아카데미아를\n'
#              '보고\n'
#              '"완전\n'
#              '점프다!!!"라며\n'
#              '문화충격을\n'
#              '받고\n'
#              '소년만화의\n'
#              '왕도에\n'
#              '대해\n'
#              '재고해본\n'
#              '뒤\n'
#              '만든\n'
#              '것이\n'
#              '주술회전.[10]\n'
#              '그래서\n'
#              '아예\n'
#              '청년\n'
#              '만화란\n'
#              '얘기를\n'
#              '듣는\n'
#              '체인소\n'
#              '맨에\n'
#              '비하면\n'
#              '그나마\n'
#              '소년만화스러운\n'
#              '부분이\n'
#              '많은\n'
#              '편이다.이렇다보니\n'
#              '소년\n'
#              '만화이지만\n'
#              '청년층의\n'
#              '독자들이\n'
#              '많다.\n'
#              '이는\n'
#              '어릴적\n'
#              '원나블을\n'
#              '접한\n'
#              '세대들이\n'
#              '시간이\n'
#              '지나\n'
#              '20~30대가\n'
#              '되면서\n'
#              '주술회전을\n'
#              '읽는\n'
#              '일이\n'
#              '많아졌기\n'
#              '때문이다.\n'
#              '작가도\n'
#              '이를\n'
#              '인정하는지\n'
#              '청년\n'
#              '독자들이\n'
#              '좋아하는\n'
#              '파격적인\n'
#              '전개를\n'
#              '시도한다.\n'
#              '이러한\n'
#              '클리셰\n'
#              '파괴는\n'
#              '연재\n'
#              '당시에는\n'
#              '호평을\n'
#              '받았으나\n'
#              '그\n'
#              '정도가\n'
#              '과해지면서\n'
#              '혹평\n'
#              '또한\n'
#              '꽤\n'
#              '나오는\n'
#              '중이다.\n'
#              '또한\n'
#              '청년층이\n'
#              '접해봤을\n'
#              '타\n'
#              '만화\n'
#              '패러디나\n'
#              '오마주가\n'
#              '많이\n'
#              '등장한다.\n'
#              '이\n'
#              '역시\n'
#              '과거에\n'
#              '소년\n'
#              '만화를\n'
#              '접한\n'
#              '독자들에게\n'
#              '익숙한\n'
#              '맛을\n'
#              '주지만,\n'
#              '혹평이\n'
#              '나오는\n'
#              '이유이기도\n'
#              '하다.개개인\n'
#              '등장인물들의\n'
#              '과거사나\n'
#              '내면\n'
#              '묘사도\n'
#              '풍부하고\n'
#              '설정도\n'
#              '방대한\n'
#              '편임에도\n'
#              '전개를\n'
#              '방해하는\n'
#              '불필요한\n'
#              '서술이\n'
#              '거의\n'
#              '없다.\n'
#              '새로운\n'
#              '인물이\n'
#              '등장할\n'
#              '때에도,\n'
#              '캐릭터의\n'
#              '성격을\n'
#              '가장\n'
#              '잘\n'
#              '표현할\n'
#              '수\n'
#              '있는\n'
#              '임팩트있는\n'
#              '에피소드\n'
#              '몇\n'
#              '컷이나\n'
#              '대사\n'
#              '몇\n'
#              '줄\n'
#              '만으로도\n'
#              '개성을\n'
#              '독자들\n'
#              '머리에\n'
#              '꽂아버리는\n'
#              '것을\n'
#              '볼\n'
#              '수\n'
#              '있다.[11]\n'
#              '전투\n'
#              '장면에서도\n'
#              '해설이\n'
#              '필요할\n'
#              '때는\n'
#              '독백이\n'
#              '아니라\n'
#              '나레이션이나\n'
#              '주변\n'
#              '인물의\n'
#              '시점에서\n'
#              '처리해\n'
#              '어색함을\n'
#              '줄이려\n'
#              '노력한\n'
#              '것이\n'
#              '보인다.[12]\n'
#              '배틀물에서\n'
#              '굳이\n'
#              '자기\n'
#              '능력을\n'
#              '구구절절\n'
#              '설명하는\n'
#              '것에도\n'
#              '파워업이라는\n'
#              '합리적인\n'
#              '이유를\n'
#              '부과하여\n'
#              '어색하지\n'
#              '않게\n'
#              '만드는\n'
#              '등\n'
#              '작가가\n'
#              '여러\n'
#              '노력을\n'
#              '기울이는\n'
#              '것을\n'
#              '알\n'
#              '수\n'
#              '있다.작화\n'
#              '평가는\n'
#              '좋지\n'
#              '않다.\n'
#              '선이\n'
#              '난잡한데\n'
#              '퀄리티가\n'
#              '들쭉날쭉\n'
#              '해서\n'
#              '편차가\n'
#              '크다.\n'
#              '비슷한\n'
#              '시기에\n'
#              '인기를\n'
#              '끈\n'
#              '귀멸의\n'
#              '칼날의\n'
#              '작화도\n'
#              '같은\n'
#              '이유로\n'
#              '평가가\n'
#              '좋지\n'
#              '않다.하지만\n'
#              '시부야\n'
#              '사변\n'
#              '에피소드부터\n'
#              '작화가\n'
#              '상당한\n'
#              '발전했는데,\n'
#              '선이\n'
#              '부드러워지면서\n'
#              '기존의\n'
#              '난잡함도\n'
#              '많이\n'
#              '사라지고\n'
#              '퀄리티도\n'
#              '일정해졌으며,\n'
#              '액션씬도\n'
#              '시원시원해졌다.\n'
#              '다만\n'
#              '시부야\n'
#              '사변\n'
#              '편까지는\n'
#              '좋은\n'
#              '평가를\n'
#              '받았지만,\n'
#              '사멸회유\n'
#              '편부터는\n'
#              '호불호가\n'
#              '갈린다.\n'
#              '물론\n'
#              '나아진\n'
#              '점도\n'
#              '있는데\n'
#              '선이\n'
#              '부드러워지고\n'
#              '가독성이\n'
#              '개선되면서\n'
#              '이전보다\n'
#              '보기는\n'
#              '훨씬\n'
#              '편해졌다.\n'
#              '다만\n'
#              '동시에\n'
#              '인물\n'
#              '외형이\n'
#              '많이\n'
#              '변했고\n'
#              '작가의\n'
#              '건강\n'
#              '탓인지\n'
#              '작붕도\n'
#              '많이\n'
#              '나온다.\n'
#              '덕분에\n'
#              '개성이\n'
#              '뚜렷해진\n'
#              '탓에\n'
#              '미남형\n'
#              '캐릭터들의\n'
#              '얼굴은\n'
#              '좋은\n'
#              '평가를\n'
#              '받지\n'
#              '못하는\n'
#              '편이다.\n'
#              '성게라는\n'
#              '별명의\n'
#              '삐죽한\n'
#              '머리인\n'
#              '후시구로\n'
#              '메구미도\n'
#              '사멸회유로\n'
#              '넘어가선\n'
#              '머리스타일이\n'
#              '비교적\n'
#              '현실적으로\n'
#              '변했고\n'
#              '애니메이션\n'
#              '1기\n'
#              '혹은\n'
#              '원작\n'
#              '초반대의\n'
#              '작화랑\n'
#              '비교해보면\n'
#              '인물들의\n'
#              '그림체가\n'
#              '많이\n'
#              "달라졌다.'사랑'과\n"
#              "'저주'가\n"
#              '작중\n'
#              '주요\n'
#              '키워드로\n'
#              '등장하는데,\n'
#              '친우애,\n'
#              '자매애,\n'
#              '가족애\n'
#              '등에\n'
#              '집중하고\n'
#              '있고\n'
#              '연애적인\n'
#              '요소는\n'
#              '없다시피\n'
#              '하다.[13]이는\n'
#              '작가가\n'
#              '의도\n'
#              '적으로\n'
#              '배제하고\n'
#              '있기\n'
#              '때문이라고\n'
#              '전시회에서\n'
#              '밝혔다.\n'
#              '유일하게\n'
#              '미와\n'
#              '카스미와\n'
#              '메카마루\n'
#              '이야기는\n'
#              '내용\n'
#              '전개상\n'
#              '어색하지\n'
#              '않을\n'
#              '것\n'
#              '같아\n'
#              '들어가게\n'
#              '되었다고.\n'
#              '실제로\n'
#              '주인공\n'
#              '3인방은\n'
#              '남2\n'
#              '여1\n'
#              '구성이지만\n'
#              '흔히\n'
#              '볼\n'
#              '수\n'
#              '있을\n'
#              '법한\n'
#              '삼각관계나\n'
#              '짝사랑\n'
#              '구도\n'
#              '없이\n'
#              '우정\n'
#              '관계로\n'
#              '그려진다.\n'
#              '주요\n'
#              '등장인물들의\n'
#              '생일은\n'
#              '모두\n'
#              '24절기의\n'
#              '날짜이다.\n'
#              '이타도리\n'
#              '유지는\n'
#              '춘분,\n'
#              '쿠기사키\n'
#              '노바라는\n'
#              '입추,\n'
#              '고죠\n'
#              '사토루는\n'
#              '대설,\n'
#              '후시구로\n'
#              '메구미는\n'
#              '동지,\n'
#              '쌍둥이\n'
#              '자매인\n'
#              '젠인\n'
#              '마키와\n'
#              '젠인\n'
#              '마이는\n'
#              '대한,\n'
#              '이누마키\n'
#              '토게는\n'
#              '상강,\n'
#              '판다는\n'
#              '경칩,\n'
#              '미와\n'
#              '카스미는\n'
#              '청명,\n'
#              '토도\n'
#              '아오이는\n'
#              '추분,\n'
#              '니시미야\n'
#              '모모는\n'
#              '소서,\n'
#              '카모\n'
#              '노리토시는\n'
#              '망종,\n'
#              '이지치\n'
#              '키요타카는\n'
#              '곡우,\n'
#              '이에이리\n'
#              '쇼코는\n'
#              '입동,\n'
#              '이오리\n'
#              '우타히메는\n'
#              '우수,\n'
#              '게토\n'
#              '스구루는\n'
#              '입춘,\n'
#              '그\n'
#              '외\n'
#              '생일이\n'
#              '밝혀진\n'
#              '캐릭터들(옷코츠\n'
#              '유타,\n'
#              '얼티밋\n'
#              '메카마루,\n'
#              '나나미\n'
#              '켄토,\n'
#              '후시구로\n'
#              '토우지\n'
#              '등)은\n'
#              '24절기\n'
#              '안에\n'
#              '들어가지\n'
#              '않는다.\n'
#              '아직\n'
#              '추가되지\n'
#              '않은\n'
#              '24절기는\n'
#              '입하,\n'
#              '소만,\n'
#              '하지,\n'
#              '대서,\n'
#              '처서,\n'
#              '백로,\n'
#              '한로,\n'
#              '소설,\n'
#              '소한이다.[14]\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0'
#              '5.\n'
#              '등장인물[편집]\n'
#              '자세한\n'
#              '내용은\n'
#              '주술회전/등장인물\n'
#              '문서를\n'
#              '참고하십시오.\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0'
#              '6.\n'
#              '설정[편집]\n'
#              '자세한\n'
#              '내용은\n'
#              '주술회전/설정\n'
#              '문서를\n'
#              '참고하십시오.\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0'
#              '7.\n'
#              '인기[편집]\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0'
#              '2021년\n'
#              '일본\n'
#              '만화\n'
#              '총선거\n'
#              '[\n'
#              '펼치기\n'
#              '·\n'
#              '접기\n'
#              ']2021년\n'
#              '1월\n'
#              '2일\n'
#              '테레비\n'
#              '아사히가\n'
#              '발표한\n'
#              '신년\n'
#              '특집\n'
#              "'만화총선거\n"
#              '일본\n'
#              '국민\n'
#              '15만명이\n'
#              '뽑은\n'
#              '좋아하는\n'
#              '만화\n'
#              '베스트\n'
#              "100'의\n"
#              '결과다.전\n'
#              '세대를\n'
#              '대상으로\n'
#              '조사했고\n'
#              '한\n'
#              '사람당\n'
#              '좋아하는\n'
#              '만화\n'
#              '5개를\n'
#              '적었다.\n'
#              '중복\n'
#              '투표는\n'
#              '금지됐다.1위《원피스》\n'
#              '(포인트:\n'
#              '33,600점)2위《귀멸의\n'
#              '칼날》\n'
#              '(29,100점)3위《슬램덩크》\n'
#              '(26,700점)4위《명탐정\n'
#              '코난》\n'
#              '(25,400점)5위《드래곤볼》\n'
#              '(22,400점)6위《진격의\n'
#              '거인》\n'
#              '(21,900점)7위《나루토》\n'
#              '(19,800점)8위《하이큐!!》\n'
#              '(18,700점)9위《강철의\n'
#              '연금술사》(18,500점)10위《죠죠의\n'
#              '기묘한\n'
#              '모험》\n'
#              '(17,100점)11위《헌터×헌터》\n'
#              '(16,200점)12위《은혼》\n'
#              '(16,100점)13위《킹덤》\n'
#              '(15,200점)14위《월드\n'
#              '트리거》\n'
#              '(11,700점)15위《도라에몽》\n'
#              '(11,300점)16위《나의\n'
#              '히어로\n'
#              '아카데미아》\n'
#              '(10,900점)17위《유유백서》\n'
#              '(8,600점)18위《블랙\n'
#              '잭》\n'
#              '(8,200점)19위《주술회전》\n'
#              '(8,000점)20위《나츠메\n'
#              '우인장》\n'
#              '(7,400점)21위《유리가면》\n'
#              '(7,100점)22위《북두의\n'
#              '권》\n'
#              '(7,000점)23위《블리치》\n'
#              '(6,950점)24위《터치》\n'
#              '(6,900점)25위《불새》\n'
#              '(6,800점)26위《바나나\n'
#              '피쉬》\n'
#              '(5,800점)27위《베르사이유의\n'
#              '장미》\n'
#              '(5,600점)28위《이누야샤》\n'
#              '(5,300점)29위《내일의\n'
#              '죠》\n'
#              '(5,100점)30위《드래곤\n'
#              '퀘스트\n'
#              '다이의\n'
#              '대모험》\n'
#              '(4,950점)31위《바람의\n'
#              '검심\n'
#              '-메이지\n'
#              '검객\n'
#              '낭만기-》\n'
#              '(4,900점)32위《메종일각》\n'
#              '(4,600점)33위《금색의\n'
#              '갓슈!!》\n'
#              '(4,400점)34위《포의\n'
#              '일족》\n'
#              '(4,100점)35위《여기는\n'
#              '잘나가는\n'
#              '파출소》\n'
#              '(4,080점)36위《고르고13》\n'
#              '(4,060점)37위《사자에상》\n'
#              '(4,040점)38위《거인의\n'
#              '별》\n'
#              '(4,020점)39위《철완\n'
#              '아톰》\n'
#              '(4,000점)40위《골든\n'
#              '카무이》\n'
#              '(3,950점)41위《도쿄\n'
#              '구울》\n'
#              '(3,900점)42위《도카벤》\n'
#              '(3,850점)43위《5등분의\n'
#              '신부》\n'
#              '(3,800점)44위《에이스를\n'
#              '노려라!》\n'
#              '(3,600점)45위《동물의사\n'
#              'Dr.스쿠르》\n'
#              '(3,450점)46위《약속의\n'
#              '네버랜드》\n'
#              '(3,400점)47위《더\n'
#              '화이팅》\n'
#              '(3,100점)48위《요괴소년\n'
#              '호야》\n'
#              '(3,000점)49위《마스터\n'
#              '키튼》\n'
#              '(2,900점)50위《카구야\n'
#              '님은\n'
#              '고백받고\n'
#              '싶어\n'
#              '~천재들의\n'
#              '연애\n'
#              '두뇌전~》\n'
#              '(2,850점)51위《암살교실》\n'
#              '(2,800점)52위《쿠로코의\n'
#              '농구》\n'
#              '(2,750점)53위《흑집사》\n'
#              '(2,700점)54위《테니스의\n'
#              '왕자》\n'
#              '(2,650점)55위《하이카라씨가\n'
#              '간다》\n'
#              '(2,600점)56위《캔디캔디》\n'
#              '(2,300점)57위《시티헌터》\n'
#              '(2,290점)58위《체인소\n'
#              '맨》\n'
#              '(2,260점)59위《노다메\n'
#              '칸타빌레》\n'
#              '(2,230점)60위《기생수》\n'
#              '(2,200점)61위《시끌별\n'
#              '녀석들》\n'
#              '(2,000점)62위《카드캡터\n'
#              '사쿠라》\n'
#              '(1,900점)63위《근육맨》\n'
#              '(1,850점)64위《문호\n'
#              '스트레이독스》\n'
#              '(1,800점)65위《페어리\n'
#              '테일》\n'
#              '(1,790점)66위《두근두근\n'
#              '투나잇》\n'
#              '(1,760점)67위《가정교사\n'
#              '히트맨\n'
#              'REBORN!》\n'
#              '(1,730점)68위《봉신연의》\n'
#              '(1,700점)69위《사이보그\n'
#              '009》\n'
#              '(1,550점)70위《꽃보다\n'
#              '남자》\n'
#              '(1,500점)71위《철인\n'
#              '28호》\n'
#              '(1,300점)72위《H2》\n'
#              '(1,250점)73위《은하철도\n'
#              '999》\n'
#              '(1,200점)74위《데빌맨》\n'
#              '(1,160점)75위《마기》\n'
#              '(1,130점)76위《맛의\n'
#              '달인》\n'
#              '(1,100점)77위《아부상》\n'
#              '(1,050점)78위《우주전함\n'
#              '야마토》\n'
#              '(1,000점)79위《바사라》\n'
#              '(990점)80위《캡틴》\n'
#              '(980점)81위《바리바리\n'
#              '전설》\n'
#              '(960점)82위《히카루의\n'
#              '바둑》\n'
#              '(950점)83위《메이저》\n'
#              '(930점)84위《불꽃\n'
#              '소방대》\n'
#              '(920점)85위《지박소년\n'
#              '하나코\n'
#              '군》\n'
#              '(900점)86위《꼭두각시\n'
#              '서커스》\n'
#              '(890점)87위《후르츠\n'
#              '바스켓》\n'
#              '(860점)88위《바람의\n'
#              '대지》\n'
#              '(830점)89위《유한클럽》\n'
#              '(800점)90위《ARIA》\n'
#              '(780점)91위《베르세르크》\n'
#              '(760점)92위《마카로니\n'
#              '호렌소》\n'
#              '(740점)93위《리본의\n'
#              '기사》\n'
#              '(720점)94위《여친,\n'
#              '빌리겠습니다》\n'
#              '(700점)95위《D.Gray-man》\n'
#              '(690점)96위《스켓》\n'
#              '(660점)97위《캡틴\n'
#              '츠바사》\n'
#              '(640점)98위《천사가\n'
#              '아니야》\n'
#              '(600점)99위《3월의\n'
#              '라이온》\n'
#              '(580점)100위《닥터\n'
#              '스톤》\n'
#              '(560점)같이\n'
#              '보기:\n'
#              '만화\n'
#              '총선거,\n'
#              '애니송\n'
#              '총선거2021년\n'
#              '발표,\n'
#              '출처\n'
#              '1\n'
#              '/\n'
#              '출처\n'
#              '2일본의\n'
#              '1억부\n'
#              '클럽\n'
#              '만화\n'
#              '[\n'
#              '펼치기\n'
#              '·\n'
#              '접기\n'
#              ']순위만화작가연재\n'
#              '기간권수수치1위원피스오다\n'
#              '에이치로1997년\n'
#              '~\n'
#              '연재\n'
#              '중111권5억\n'
#              '2000만부2위고르고13사이토\n'
#              '타카오1968년\n'
#              '~\n'
#              '연재\n'
#              '중208권3억\n'
#              '100만부3위명탐정\n'
#              '코난아오야마\n'
#              '고쇼1994년\n'
#              '~\n'
#              '연재\n'
#              '중107권2억\n'
#              '7,000만부4위드래곤볼토리야마\n'
#              '아키라1984년\n'
#              '~\n'
#              '1995년42권2억\n'
#              '6,000만부5위나루토키시모토\n'
#              '마사시1999년\n'
#              '~\n'
#              '2014년72권2억\n'
#              '5,000만부6위슬램덩크이노우에\n'
#              '다케히코1990년\n'
#              '~\n'
#              '1996년31권1억\n'
#              '8,500만부7위여기는\n'
#              '잘나가는\n'
#              '파출소아키모토\n'
#              '오사무1976년\n'
#              '~\n'
#              '2016년201권1억\n'
#              '5,650만부8위귀멸의\n'
#              '칼날고토게\n'
#              '코요하루2016년\n'
#              '~\n'
#              '2020년23권1억\n'
#              '5,000만부9위진격의\n'
#              '거인이사야마\n'
#              '하지메2009년\n'
#              '~\n'
#              '2021년34권1억\n'
#              '4,000만부10위맛의\n'
#              '달인카리야\n'
#              '테츠(원작)하나사키\n'
#              '아키라(그림)1983년\n'
#              '~\n'
#              '2014년(휴재)111권1억\n'
#              '3,500만부11위블리치쿠보\n'
#              '타이토2001년\n'
#              '~\n'
#              '2016년74권1억\n'
#              '3,000만부12위죠죠의\n'
#              '기묘한\n'
#              '모험아라키\n'
#              '히로히코1987년\n'
#              '~\n'
#              '연재\n'
#              '중131권\n'
#              '1억\n'
#              '2,000만부13위킹덤하라\n'
#              '야스히사2006년\n'
#              '~\n'
#              '연재\n'
#              '중74권1억\n'
#              '1,000만부14위철완\n'
#              '아톰데즈카\n'
#              '오사무1952년\n'
#              '~\n'
#              '1968년23권1억부도라에몽후지코\n'
#              'F.\n'
#              '후지오1969년\n'
#              '~\n'
#              '1996년45권1억부터치아다치\n'
#              '미츠루1981년\n'
#              '~\n'
#              '1986년26권1억부북두의\n'
#              '권부론손(스토리)하라\n'
#              '테츠오(작화)1983년\n'
#              '~\n'
#              '1988년27권1억부더\n'
#              '화이팅모리카와\n'
#              '죠지1989년\n'
#              '~\n'
#              '연재\n'
#              '중141권1억부바키\n'
#              '시리즈이타가키\n'
#              '케이스케1991년\n'
#              '~\n'
#              '연재\n'
#              '중150권1억부소년탐정\n'
#              '김전일아마기\n'
#              '세이마루\n'
#              '(원작)카나리\n'
#              '요자부로\n'
#              '(원작)사토\n'
#              '후미야\n'
#              '(작화)1992년\n'
#              '~\n'
#              '연재\n'
#              '중83권1억부나의\n'
#              '히어로\n'
#              '아카데미아호리코시\n'
#              '코헤이2014년\n'
#              '~\n'
#              '2024년42권1억부주술회전아쿠타미\n'
#              '게게2018년\n'
#              '~\n'
#              '2024년30권1억부출처2020년대\n'
#              '가장\n'
#              '성공한\n'
#              '일본\n'
#              '만화\n'
#              '중\n'
#              '하나로\n'
#              '꼽힌다.\n'
#              '회옥\n'
#              '옥절편과\n'
#              '시부야\n'
#              '사변편의\n'
#              '좋은\n'
#              '평가로\n'
#              '인기가\n'
#              '급상승하였으며,\n'
#              '2020년\n'
#              '연간\n'
#              '오리콘\n'
#              '차트\n'
#              '만화\n'
#              '판매량에서\n'
#              '5위를\n'
#              '차지하며\n'
#              '인기작\n'
#              '반열에\n'
#              '올라섰음을\n'
#              '증명했다.\n'
#              '2020년\n'
#              '일본\n'
#              '트위터\n'
#              '만화\n'
#              '트렌드\n'
#              '3위에\n'
#              '랭크되면서\n'
#              '넷상\n'
#              '화제성도\n'
#              '최상위권으로\n'
#              '올라섰다.\n'
#              '2020년\n'
#              '4분기부터\n'
#              '방영하고\n'
#              '있는\n'
#              '애니메이션이\n'
#              '인기를\n'
#              '끌면서\n'
#              '원작의\n'
#              '인기\n'
#              '역시\n'
#              '종횡무진\n'
#              '중.\n'
#              '2021년\n'
#              '3월,\n'
#              '15권이\n'
#              '오리콘\n'
#              '초동\n'
#              '판매부수\n'
#              '113만권을\n'
#              '기록,\n'
#              '2021년\n'
#              '9월,\n'
#              '17권이\n'
#              '초판\n'
#              '발행부수\n'
#              '215만부를\n'
#              '기록했다.\n'
#              '이는\n'
#              '2021년\n'
#              '한정으로\n'
#              '일본\n'
#              '현역\n'
#              '만화\n'
#              '중\n'
#              '원피스\n'
#              '다음\n'
#              '가는\n'
#              '단권\n'
#              '판매량이다.[15]\n'
#              '같은\n'
#              '잡지에서\n'
#              '연재되는\n'
#              '귀멸의\n'
#              '칼날의\n'
#              '뒤를\n'
#              '이은\n'
#              '점프의\n'
#              '대표작\n'
#              '중\n'
#              '하나로\n'
#              '자리매김했고[16]\n'
#              '기어이\n'
#              '2021년\n'
#              '결산\n'
#              '오리콘\n'
#              '차트\n'
#              '1위를\n'
#              '차지했다.또한\n'
#              '2021년\n'
#              '일본\n'
#              '트위터에서\n'
#              '가장\n'
#              '많이\n'
#              '트윗된\n'
#              '만화\n'
#              '해시태그\n'
#              '1위에\n'
#              '올랐다.[17]극장판\n'
#              '주술회전\n'
#              '0은\n'
#              '흥행\n'
#              '수입\n'
#              '138억엔을\n'
#              '돌파하였으며\n'
#              '전세계적으로는\n'
#              '북미\n'
#              '3400만\n'
#              '달러를\n'
#              '포함\n'
#              '무려\n'
#              '1억\n'
#              '9천만\n'
#              '달러를\n'
#              '기록하면서\n'
#              '대성공했다.2022년에도\n'
#              '잘\n'
#              '팔리면서\n'
#              '7천만부를\n'
#              '달성했다.\n'
#              '오리콘\n'
#              '차트에서\n'
#              '1위를\n'
#              '아슬아슬하게\n'
#              '유지하며,\n'
#              '결국\n'
#              '2년\n'
#              '연속\n'
#              '1위를\n'
#              '차지했다.리디어워즈만화\n'
#              '최우수상\n'
#              '[\n'
#              '펼치기\n'
#              '·\n'
#              '접기\n'
#              ']2020년2021년2022년2023년월간순정\n'
#              '노자키\n'
#              '군던전밥주술회전여학교의\n'
#              '별2024년사카모토\n'
#              '데이즈만화\n'
#              '대상\n'
#              '▶\n'
#              '또한\n'
#              '국내\n'
#              '독자들의\n'
#              '투표로\n'
#              '선정되는\n'
#              '리디어워즈에서도\n'
#              '2022년\n'
#              '최우수상을\n'
#              '수상하였다.2023년은\n'
#              '아쉽게도\n'
#              '천만부\n'
#              '돌파에\n'
#              '실패하며\n'
#              '1052만부를\n'
#              '돌파한\n'
#              '블루\n'
#              '록에게\n'
#              '1위\n'
#              '자리를\n'
#              '내주며\n'
#              '2위를\n'
#              '기록했다.\n'
#              '하지만\n'
#              '완결이\n'
#              '난\n'
#              '해인\n'
#              '2024년에\n'
#              '다시금\n'
#              '1위를\n'
#              '탈환하면서\n'
#              '유종의\n'
#              '미를\n'
#              '거두었다.2024년\n'
#              '1월,\n'
#              '기네스\n'
#              '세계\n'
#              '기록(기네스북)에\n'
#              '전세계\n'
#              '모든\n'
#              'TV\n'
#              '프로그램\n'
#              '중\n'
#              '가장\n'
#              '수요높은\n'
#              'TV쇼로\n'
#              '기존\n'
#              '기록의\n'
#              '68.2배에\n'
#              '3%p\n'
#              '더\n'
#              '오른\n'
#              '71.2배의\n'
#              '수요\n'
#              '기록을\n'
#              '갱신하며\n'
#              '등재되었으며#\n'
#              '2024년\n'
#              'Global\n'
#              'TV\n'
#              'Demand\n'
#              'Awards에서도\n'
#              '2023년에\n'
#              '방영된\n'
#              '전세계\n'
#              '모든\n'
#              'TV\n'
#              '프로그램\n'
#              '중\n'
#              '가장\n'
#              '수요가\n'
#              '높은\n'
#              'TV쇼로\n'
#              '선정되었다.#,\n'
#              '기네스\n'
#              '피셜로\n'
#              '2023년\n'
#              '가장\n'
#              '인기있는\n'
#              '애니메이션\n'
#              'TV쇼로도\n'
#              '기록되었다.#특히\n'
#              '서양\n'
#              '문화권에서\n'
#              '흔히\n'
#              '생각하는\n'
#              '동양\n'
#              '오리엔탈리즘\n'
#              '요소와\n'
#              '더불어\n'
#              '이러한\n'
#              '면모가\n'
#              '존재했던\n'
#              '나루토와\n'
#              '블리치의\n'
#              '서양\n'
#              '팬덤을\n'
#              '이어받으면서\n'
#              '큰\n'
#              '인기를\n'
#              '자랑했다.\n'
#              '게임\n'
#              '포트나이트와\n'
#              '콜라보도\n'
#              '나왔을\n'
#              "정도.'영역\n"
#              "전개'라는\n"
#              '단어\n'
#              '자체가\n'
#              '일본\n'
#              '내\n'
#              '10대들의\n'
#              '유행어로\n'
#              '등극한\n'
#              '것은\n'
#              '물론\n'
#              '한국의\n'
#              '주술회전\n'
#              '덕후들\n'
#              '사이에서도\n'
#              '인기를\n'
#              '끌기도\n'
#              '했다.\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0'
#              '7.1.\n'
#              '누계\n'
#              '발행\n'
#              '부수[편집]\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0'
#              '일본의\n'
#              '1억부\n'
#              '클럽\n'
#              '만화\n'
#              '[\n'
#              '펼치기\n'
#              '·\n'
#              '접기\n'
#              ']순위만화작가연재\n'
#              '기간권수수치1위원피스오다\n'
#              '에이치로1997년\n'
#              '~\n'
#              '연재\n'
#              '중111권5억\n'
#              '2000만부2위고르고13사이토\n'
#              '타카오1968년\n'
#              '~\n'
#              '연재\n'
#              '중208권3억\n'
#              '100만부3위명탐정\n'
#              '코난아오야마\n'
#              '고쇼1994년\n'
#              '~\n'
#              '연재\n'
#              '중107권2억\n'
#              '7,000만부4위드래곤볼토리야마\n'
#              '아키라1984년\n'
#              '~\n'
#              '1995년42권2억\n'
#              '6,000만부5위나루토키시모토\n'
#              '마사시1999년\n'
#              '~\n'
#              '2014년72권2억\n'
#              '5,000만부6위슬램덩크이노우에\n'
#              '다케히코1990년\n'
#              '~\n'
#              '1996년31권1억\n'
#              '8,500만부7위여기는\n'
#              '잘나가는\n'
#              '파출소아키모토\n'
#              '오사무1976년\n'
#              '~\n'
#              '2016년201권1억\n'
#              '5,650만부8위귀멸의\n'
#              '칼날고토게\n'
#              '코요하루2016년\n'
#              '~\n'
#              '2020년23권1억\n'
#              '5,000만부9위진격의\n'
#              '거인이사야마\n'
#              '하지메2009년\n'
#              '~\n'
#              '2021년34권1억\n'
#              '4,000만부10위맛의\n'
#              '달인카리야\n'
#              '테츠(원작)하나사키\n'
#              '아키라(그림)1983년\n'
#              '~\n'
#              '2014년(휴재)111권1억\n'
#              '3,500만부11위블리치쿠보\n'
#              '타이토2001년\n'
#              '~\n'
#              '2016년74권1억\n'
#              '3,000만부12위죠죠의\n'
#              '기묘한\n'
#              '모험아라키\n'
#              '히로히코1987년\n'
#              '~\n'
#              '연재\n'
#              '중131권\n'
#              '1억\n'
#              '2,000만부13위킹덤하라\n'
#              '야스히사2006년\n'
#              '~\n'
#              '연재\n'
#              '중74권1억\n'
#              '1,000만부14위철완\n'
#              '아톰데즈카\n'
#              '오사무1952년\n'
#              '~\n'
#              '1968년23권1억부도라에몽후지코\n'
#              'F.\n'
#              '후지오1969년\n'
#              '~\n'
#              '1996년45권1억부터치아다치\n'
#              '미츠루1981년\n'
#              '~\n'
#              '1986년26권1억부북두의\n'
#              '권부론손(스토리)하라\n'
#              '테츠오(작화)1983년\n'
#              '~\n'
#              '1988년27권1억부더\n'
#              '화이팅모리카와\n'
#              '죠지1989년\n'
#              '~\n'
#              '연재\n'
#              '중141권1억부바키\n'
#              '시리즈이타가키\n'
#              '케이스케1991년\n'
#              '~\n'
#              '연재\n'
#              '중150권1억부소년탐정\n'
#              '김전일아마기\n'
#              '세이마루\n'
#              '(원작)카나리\n'
#              '요자부로\n'
#              '(원작)사토\n'
#              '후미야\n'
#              '(작화)1992년\n'
#              '~\n'
#              '연재\n'
#              '중83권1억부나의\n'
#              '히어로\n'
#              '아카데미아호리코시\n'
#              '코헤이2014년\n'
#              '~\n'
#              '2024년42권1억부주술회전아쿠타미\n'
#              '게게2018년\n'
#              '~\n'
#              '2024년30권1억부출처전\n'
#              '세계의\n'
#              '만화\n'
#              '판매\n'
#              '순위\n'
#              '[\n'
#              '펼치기\n'
#              '·\n'
#              '접기\n'
#              ']순위만화국가연재\n'
#              '기간권수수치1위슈퍼맨미국1938년\n'
#              '~\n'
#              '연재\n'
#              '중18732화6억부2위원피스일본1997년\n'
#              '~\n'
#              '연재\n'
#              '중110권5억\n'
# ...
#              '자세한\n'
#              '내용은\n'
#              '주술회전\n'
#              '팬텀\n'
#              '퍼레이드\n'
#              '문서를\n'
#              '참고하십시오.\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0'
#              '9.4.2.\n'
#              '주술회전\n'
#              '전화향명[편집]\n'
#              '자세한\n'
#              '내용은\n'
#              '주술회전\n'
#              '전화향명\n'
#              '문서를\n'
#              '참고하십시오.\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0'
#              '9.5.\n'
#              '콜라보레이션[편집]\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0'
#              'Ninjala\n'
#              '자세한\n'
#              '내용은\n'
#              'Ninjala/콜라보레이션\n'
#              '및\n'
#              '관련\n'
#              '상품\n'
#              '문서의\n'
#              '1.9번\n'
#              '문단을\n'
#              '참고하십시오.배틀그라운드\n'
#              '모바일포트나이트/배틀로얄치장아이템인\n'
#              '스킨을\n'
#              '판매하며,\n'
#              '언락\n'
#              '퀘스트로만\n'
#              '얻을\n'
#              '수\n'
#              '있는\n'
#              '일부\n'
#              '비매품\n'
#              '한정\n'
#              '스킨도\n'
#              '출시되었다.\n'
#              '그리고\n'
#              '기간\n'
#              '한정으로\n'
#              '인게임에\n'
#              '등장하는\n'
#              '무기\n'
#              '또한\n'
#              '추가되었다.산리오\n'
#              '캐릭터즈2022년,\n'
#              '2024년\n'
#              '두\n'
#              '번에\n'
#              '걸쳐\n'
#              '콜라보하였다.\n'
#              '10.\n'
#              '기타[편집]\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0'
#              '2017년\n'
#              '점프GIGA에서\n'
#              '연재됐던\n'
#              '4화\n'
#              '완결\n'
#              '단편인\n'
#              '도쿄\n'
#              '도립\n'
#              '주술\n'
#              '고등전문학교와\n'
#              '같은\n'
#              '세계관을\n'
#              '공유한\n'
#              '작품이다.\n'
#              '보통\n'
#              '단편은\n'
#              '정식연재\n'
#              '때\n'
#              '어느\n'
#              '정도\n'
#              '변형을\n'
#              '거치는데\n'
#              '비해\n'
#              '이쪽은\n'
#              '단편은\n'
#              '그대로\n'
#              '유지하고\n'
#              '그로부터\n'
#              '1년\n'
#              '뒤의\n'
#              '이야기를\n'
#              '다뤘다.일본\n'
#              '여학생이\n'
#              '선택한\n'
#              '2021년\n'
#              '트렌드\n'
#              '예측에서\n'
#              '1위를\n'
#              '차지했다.요미우리\n'
#              '자이언츠와\n'
#              '콜라보를\n'
#              '해서\n'
#              '기념품을\n'
#              '출시하기도\n'
#              '했다.작가\n'
#              '아쿠타미\n'
#              '게게가\n'
#              '2021년에\n'
#              '한\n'
#              '인터뷰에서\n'
#              '약\n'
#              '2년\n'
#              '내로\n'
#              '주술회전을\n'
#              '완결할\n'
#              '계획을\n'
#              '밝혔으나\n'
#              '휴재\n'
#              '시기를\n'
#              '고려한다면\n'
#              '좀\n'
#              '더\n'
#              '길어질\n'
#              '가능성이\n'
#              '높았다.\n'
#              '그리고\n'
#              '예상\n'
#              '시기로부터\n'
#              '1년을\n'
#              '더\n'
#              '연재하고\n'
#              '2024년\n'
#              '9월\n'
#              '30일자로\n'
#              '완결되었다.정발판은\n'
#              '초반부터\n'
#              '시부야\n'
#              '사변\n'
#              '후반부까지\n'
#              '검열이\n'
#              '있다.\n'
#              '반응이\n'
#              '많이\n'
#              '안\n'
#              '좋았는지\n'
#              '그\n'
#              '이후부터는\n'
#              '잔인한\n'
#              '장면도\n'
#              '검열\n'
#              '없이\n'
#              '나온다.애니메이션판의\n'
#              '경우\n'
#              '대한민국과\n'
#              '인연이\n'
#              '깊은\n'
#              '작품으로\n'
#              '유명하다.\n'
#              '2020년에\n'
#              '갓\n'
#              '오브\n'
#              '하이스쿨\n'
#              '애니와\n'
#              '함께\n'
#              '주술회전\n'
#              '1기를\n'
#              '당시\n'
#              'MAPPA에서\n'
#              '활동하고\n'
#              '있었던\n'
#              '박성후\n'
#              '감독이\n'
#              '맡아서\n'
#              '화제가\n'
#              '되었고,\n'
#              '1년\n'
#              '뒤인\n'
#              '2021년에\n'
#              '극장판\n'
#              '주술회전\n'
#              '0까지\n'
#              '맡았으며\n'
#              '한국에서도\n'
#              '개봉되면서\n'
#              '대중들에게도\n'
#              '알려지게\n'
#              '되었다.\n'
#              '원작에서도\n'
#              '마동석을\n'
#              '모티브로\n'
#              '했다는\n'
#              '공시우라는\n'
#              '한국인\n'
#              '캐릭터가\n'
#              '등장해\n'
#              '팬북에서\n'
#              "'(작가가\n"
#              '생각하기에)\n'
#              '과거편에서\n'
#              '제일\n'
#              '멋진\n'
#              "인물'이라고\n"
#              '평가받기도\n'
#              '했다.[20]제목의\n'
#              '주술이\n'
#              '유술과\n'
#              '발음이\n'
#              '비슷하고[21]\n'
#              '장음이\n'
#              '생략된\n'
#              '영어\n'
#              '표기는\n'
#              '아예\n'
#              '유술의\n'
#              '영어\n'
#              '표기와\n'
#              '동일한지라\n'
#              '영어\n'
#              '제목만\n'
#              '보면\n'
#              '유술(주짓수)과\n'
#              '무슨\n'
#              '관련이\n'
#              '있는지\n'
#              '의문을\n'
#              '가지거나\n'
#              '주짓수\n'
#              '드립\n'
#              '치는\n'
#              '사람들이\n'
#              '간혹\n'
#              '보인다.#\n'
#              '#\n'
#              '+ccAq7hx+ccAq7hx\n'
#              '[1]\n'
#              '2018.\n'
#              '03.\n'
#              '05.\n'
#              '~\n'
#              '2024.\n'
#              '09.\n'
#              '30.[2]\n'
#              '싸움(戰)이\n'
#              '계속\n'
#              '반복됨(廻)으로\n'
#              '해석할\n'
#              '수\n'
#              '있다.[3]\n'
#              '작가의\n'
#              '이전\n'
#              '작인\n'
#              "'도쿄\n"
#              '도립\n'
#              '주술\n'
#              "고등전문학교'를\n"
#              '단행본\n'
#              '0권으로\n'
#              '발매했다.[4]\n'
#              '잡고\n'
#              '있는\n'
#              '손은\n'
#              '각각\n'
#              '동생들인\n'
#              '에소우와\n'
#              '케치즈[5]\n'
#              '왼쪽\n'
#              '상단을\n'
#              '보면\n'
#              '쌍둥이인\n'
#              '젠인\n'
#              '마이와\n'
#              '새끼\n'
#              '손가락을\n'
#              '걸고\n'
#              '있다.[6]\n'
#              '이렇다\n'
#              '보니\n'
#              '소년\n'
#              '점프의\n'
#              '패러디가\n'
#              '많은\n'
#              '나와\n'
#              '로보코에서는\n'
#              '소년\n'
#              '점프\n'
#              '입문자에게는\n'
#              '추천되지\n'
#              '않는\n'
#              '입문작이라는\n'
#              '언급이\n'
#              '나온다.\n'
#              '애초에\n'
#              '소년\n'
#              '점프의\n'
#              '클리셰를\n'
#              '부수는\n'
#              '전개가\n'
#              '많다보니\n'
#              '어린\n'
#              '독자들이나\n'
#              '입문자들에게는\n'
#              '와닿지\n'
#              '않는\n'
#              '부분이\n'
#              '많기도하다.[7]\n'
#              '학교에선\n'
#              '따돌림을\n'
#              '당하고,\n'
#              '이\n'
#              '사실을\n'
#              '알면서도\n'
#              '선생들은\n'
#              '눈을\n'
#              '돌린다.\n'
#              '이러한\n'
#              '현실\n'
#              '속에서\n'
#              '무력하게\n'
#              '살아가던\n'
#              '준페이는\n'
#              '마히토를\n'
#              '만나\n'
#              '힘을\n'
#              '얻게\n'
#              '되고,\n'
#              '이타도리\n'
#              '유지라는\n'
#              '친구도\n'
#              '생기지만\n'
#              '어느\n'
#              '날\n'
#              '누군가의\n'
#              '계략에\n'
#              '의해\n'
#              '유일한\n'
#              '가족인\n'
#              '어머니를\n'
#              '잃고\n'
#              '엇나가기\n'
#              '시작한다.[8]\n'
#              '비록\n'
#              '그\n'
#              '상대가\n'
#              '강제적인\n'
#              '인체\n'
#              '개조로\n'
#              '돌이킬\n'
#              '수\n'
#              '없는\n'
#              '몸이\n'
#              '된\n'
#              '개조\n'
#              '인간이었음을\n'
#              '감안해도.[9]\n'
#              '참고로\n'
#              '지금에\n'
#              '와서\n'
#              '돌아보면\n'
#              '그냥\n'
#              '재미가\n'
#              '없었다고\n'
#              '평가했다.\n'
#              '프리큐어\n'
#              '시리즈\n'
#              '같은\n'
#              '소녀\n'
#              '격투물이었다고.[10]\n'
#              '단행본\n'
#              '5권\n'
#              '부록에\n'
#              '호리코시\n'
#              '코헤이\n'
#              '작가와의\n'
#              '교환\n'
#              '일러스트와\n'
#              '함께\n'
#              '실린\n'
#              '이야기.\n'
#              '아쿠타미\n'
#              '게게\n'
#              '작가의\n'
#              '일러스트는\n'
#              '히로아카\n'
#              '23권에\n'
#              '실렸다.[11]\n'
#              '대표적으로\n'
#              '히구루마\n'
#              '히로미는\n'
#              '무려\n'
#              '등장\n'
#              '회차가\n'
#              '3화밖에\n'
#              '되지\n'
#              '않음에도\n'
#              '불구하고,\n'
#              '캐릭터성을\n'
#              '독자들의\n'
#              '뇌리에\n'
#              '완벽히\n'
#              '새기는\n'
#              '것에\n'
#              '성공했다.[12]\n'
#              '예를\n'
#              '들어\n'
#              '고죠가\n'
#              '옥문강에서\n'
#              '풀려나고\n'
#              '한\n'
#              '달\n'
#              '후에\n'
#              '스쿠나와\n'
#              '결전을\n'
#              '벌이기로\n'
#              '약속했는데,\n'
#              '보통의\n'
#              '소년\n'
#              '만화였다면\n'
#              '그간의\n'
#              '준비\n'
#              '기간을\n'
#              '연재했겠지만\n'
#              '주술회전은\n'
#              '그런\n'
#              '거\n'
#              '없이\n'
#              '한\n'
#              '달을\n'
#              '날려버리고\n'
#              '다음\n'
#              '화에\n'
#              '바로\n'
#              '붙어버린다(...).\n'
#              '그리고\n'
#              '차후\n'
#              '전개에서\n'
#              '간간히\n'
#              '회상식으로나마\n'
#              '나오고\n'
#              '있다.[13]\n'
#              '연애\n'
#              '요소가\n'
#              '직접적으로\n'
#              '다루어진\n'
#              '것은\n'
#              '0권의\n'
#              '옷코츠-리카\n'
#              '이야기와\n'
#              '후시구로\n'
#              '토우지-후시구로\n'
#              '메구미의\n'
#              '친모\n'
#              '이야기\n'
#              '정도인데,\n'
#              '둘\n'
#              '다\n'
#              '한\n'
#              '쪽이\n'
#              '이미\n'
#              '고인인데다\n'
#              '본편에서는\n'
#              '사실상\n'
#              '등장하지\n'
#              '않는다는\n'
#              '공통점이\n'
#              '있다.[14]\n'
#              '현재까지\n'
#              '봄에\n'
#              '해당하는\n'
#              '절기들은\n'
#              '다\n'
#              '모였다.[15]\n'
#              '다만\n'
#              '오피셜\n'
#              '통계를\n'
#              '작성시에는\n'
#              '조금\n'
#              '유의해야\n'
#              '하는데,\n'
#              '실제\n'
#              '일본\n'
#              '내의\n'
#              '관련\n'
#              '기록\n'
#              '통계에서는\n'
#              '당해년도\n'
#              '판매\n'
#              '기록을\n'
#              '전년도\n'
#              '12월부터\n'
#              '당해년도\n'
#              '11월까지를\n'
#              '집계하기\n'
#              '때문에,\n'
#              '문자\n'
#              '그대로\n'
#              '2021년을\n'
#              '기준으로\n'
#              '하면\n'
#              '맞는\n'
#              '이야기이나,\n'
#              '관련\n'
#              '기록\n'
#              '통계\n'
#              '작성\n'
#              '환경상\n'
#              '20년\n'
#              '12월에\n'
#              '발매한\n'
#              '귀멸의\n'
#              '칼날\n'
#              '23권이\n'
#              '있기\n'
#              '때문에,\n'
#              '정확하게\n'
#              '확인해서\n'
#              '작성해야\n'
#              '한다.[16]\n'
#              '귀멸이\n'
#              '최종국면을\n'
#              '연재하던\n'
#              '시점에\n'
#              '주술회전은\n'
#              '시부야\n'
#              '사변이\n'
#              '연재되고\n'
#              '있었다.[17]\n'
#              '다른\n'
#              '만화도\n'
#              '아니고\n'
#              '그\n'
#              '귀멸의\n'
#              '칼날을\n'
#              '제치고\n'
#              '1위를\n'
#              '차지했다![18]\n'
#              '사실\n'
#              '그\n'
#              '모든\n'
#              '것\n'
#              '이전에\n'
#              '고죠\n'
#              '사토루의\n'
#              '죽음이라는\n'
#              '파급력이\n'
#              '너무\n'
#              '커서\n'
#              '그\n'
#              '외의\n'
#              '단점이\n'
#              '작아보일\n'
#              '뿐이라는\n'
#              '평가마저\n'
#              '있기도\n'
#              '했다.[19]\n'
#              '주술회전\n'
#              '소설판\n'
#              '외에는\n'
#              '키시베\n'
#              '로한은\n'
#              '움직이지\n'
#              '않는다\n'
#              '단편\n'
#              '소설집\n'
#              '시리즈에\n'
#              '투고한\n'
#              '적이\n'
#              '있다.[20]\n'
#              '고죠와\n'
#              '게토의\n'
#              '호위\n'
#              '대상인\n'
#              '아마나이\n'
#              '리코의\n'
#              '암살\n'
#              '의뢰를\n'
#              '주선하는,\n'
#              '악역에\n'
#              '가까운\n'
#              '인물이었지만\n'
#              '과거편의\n'
#              '메인\n'
#              '악역인\n'
#              '후시구로\n'
#              '토우지의\n'
#              '보조역\n'
#              '수준에\n'
#              '머물러\n'
#              '악인이라는\n'
#              '인상은\n'
#              '옅다.[21]\n'
#              '장음\n'
#              '하나\n'
#              '차이.\n'
#              '유술(じゅうじゅつ)\n'
#              '주술(じゅじゅつ)\n'
#              '이\n'
#              '저작물은\n'
#              'CC\n'
#              'BY-NC-SA\n'
#              '2.0\n'
#              'KR에\n'
#              '따라\n'
#              '이용할\n'
#              '수\n'
#              '있습니다.\n'
#              '(단,\n'
#              '라이선스가\n'
#              '명시된\n'
#              '일부\n'
#              '문서\n'
#              '및\n'
#              '삽화\n'
#              '제외)기여하신\n'
#              '문서의\n'
#              '저작권은\n'
#              '각\n'
#              '기여자에게\n'
#              '있으며,\n'
#              '각\n'
#              '기여자는\n'
#              '기여하신\n'
#              '부분의\n'
#              '저작권을\n'
#              '갖습니다.나무위키는\n'
#              '백과사전이\n'
#              '아니며\n'
#              '검증되지\n'
#              '않았거나,\n'
#              '편향적이거나,\n'
#              '잘못된\n'
#              '서술이\n'
#              '있을\n'
#              '수\n'
#              '있습니다.나무위키는\n'
#              '위키위키입니다.\n'
#              '여러분이\n'
#              '직접\n'
#              '문서를\n'
#              '고칠\n'
#              '수\n'
#              '있으며,\n'
#              '다른\n'
#              '사람의\n'
#              '의견을\n'
#              '원할\n'
#              '경우\n'
#              '직접\n'
#              '토론을\n'
#              '발제할\n'
#              '수\n'
#              '있습니다.\n'
#              '더\n'
#              '보기\n'
#              'namu.wikiContáctenosTérminos\n'
#              'de\n'
#              'usoOperado\n'
#              'por\n'
#              'umanle\n'
#              'S.R.L.Hecho\n'
#              'con\n'
#              '❤️\n'
#              'en\n'
#              'Asunción,\n'
#              'República\n'
#              'del\n'
#              'Paraguay\n'
#              'Su\n'
#              'zona\n'
#              'horaria\n'
#              'es\n'
#              'GMTImpulsado\n'
#              'por\n'
#              'the\n'
#              'seed\n'
#              'engine\n'
#              'This\n'
#              'site\n'
#              'is\n'
#              'protected\n'
#              'by\n'
#              'reCAPTCHA\n'
#              'and\n'
#              'the\n'
#              'Google\n'
#              'Privacy\n'
#              'Policy\n'
#              'and\n'
#              'Terms\n'
#              'of\n'
#              'Service\n'
#              'apply.\n'
#              'This\n'
#              'site\n'
#              'is\n'
#              'protected\n'
#              'by\n'
#              'hCaptcha\n'
#              'and\n'
#              'its\n'
#              'Privacy\n'
#              'Policy\n'
#              'and\n'
#              'Terms\n'
#              'of\n'
#              'Service\n'
#              'apply. /no_think',
#   'name': 'web_search',
#   'role': 'tool'}]

# %%
response = chat(
    model="qwen3:8b",
    messages=messages,
    tools=ollama_tools,
    keep_alive = -1
)

print("STEP 3: Final Answer")
pprint.pprint(response["message"]["content"])
# Out:
# STEP 3: Final Answer
# ('<think>\n'
#  '\n'
#  '</think>\n'
#  '\n'
#  "It looks like you've pasted a long block of text that seems to be a mix of "
#  'content from a Korean webtoon or manga, possibly **"Jujutsu Kaisen" '
#  '(咒术回战)**, along with some metadata, footnotes, and possibly some unrelated '
#  "text or formatting issues. Here's a breakdown of what I see:\n"
#  '\n'
#  '---\n'
#  '\n'
#  '### 📖 **Main Content: "Jujutsu Kaisen" (咒术回战)**\n'
#  '\n'
#  'This appears to be a **summary or analysis** of the manga *Jujutsu Kaisen* '
#  '(which translates to "Jujutsu Battle") by **Gege Akutami**. It includes:\n'
#  '\n'
#  '- **Characters** like:\n'
#  '  - **Gojo Satoru**\n'
#  '  - **Megumi Fushiguro**\n'
#  '  - **Toge Inuishi**\n'
#  '  - **Tsuji Satoru**\n'
#  '  - **Haguro Hiroto**\n'
#  '- **Plot points**:\n'
#  '  - The **"Satoru Gojo" arc**\n'
#  '  - The **"Shinigami" arc**\n'
#  '  - **Kasugano** and the **Cursed Techniques**\n'
#  '  - **Cursed Wands**, **Cursed Spirits**, and **Cursed Techniques**\n'
#  '- **Themes**:\n'
#  '  - **Power and responsibility**\n'
#  '  - **Love and loss**\n'
#  '  - **The cost of power**\n'
#  '  - **The burden of being a hero**\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 📚 **Other Content**\n'
#  '\n'
#  'There are also **footnotes and references** that indicate this text may have '
#  'been:\n'
#  '\n'
#  '- **A fan-made summary or analysis**\n'
#  '- **A translated version** of a Korean blog or article about *Jujutsu '
#  'Kaisen*\n'
#  '- **Includes some footnotes** (e.g., [1], [2], etc.) that reference specific '
#  'parts of the manga or author details\n'
#  '- **Metadata** about the creation date and source (e.g., "2018.03.05. ~ '
#  '2024.09.30")\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 📝 **Unrelated Text / Formatting Issues**\n'
#  '\n'
#  'Some parts of the text seem to be **formatting errors**, **non-English '
#  'text**, or **incorrectly formatted** notes, such as:\n'
#  '\n'
#  '- `+ccAq7hx+ccAq7hx`\n'
#  '- `#`\n'
#  '- `This site is protected by reCAPTCHA...`\n'
#  '- `Hecho con ❤️ en Asunción, República del Paraguay...`\n'
#  '\n'
#  'These are likely **artifacts from a web page or a translation error**.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 🧠 **What You Can Do**\n'
#  '\n'
#  'If you want to **clean up** this text, you can:\n'
#  '\n'
#  '1. **Remove the formatting artifacts** like `+ccAq7hx+ccAq7hx` and `#`\n'
#  '2. **Extract the key information** about *Jujutsu Kaisen*\n'
#  '3. **Format it into a readable summary or analysis**\n'
#  '4. **Use it as a reference** for understanding the plot, characters, and '
#  'themes of the series\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### ✅ **Summary of "Jujutsu Kaisen" (咒术回战)**\n'
#  '\n'
#  '**"Jujutsu Kaisen"** is a popular Japanese manga written by **Gege '
#  'Akutami**. It follows the story of **Satoru Gojo**, a powerful high school '
#  'student who becomes a **jujutsu sorcerer** and must fight against **cursed '
#  'spirits** to protect his classmates and loved ones.\n'
#  '\n'
#  '- **Main Characters**:\n'
#  '  - **Gojo Satoru**: A genius sorcerer with the **"Limitless"** ability.\n'
#  '  - **Megumi Fushiguro**: A sorcerer who wields a **cursed wand**.\n'
#  '  - **Toge Inuishi**: A sorcerer who wields a **cursed technique** called '
#  '**"Toge\'s Needle"**.\n'
#  '  - **Tsuji Satoru**: A sorcerer who wields a **cursed technique** called '
#  '**"Cursed Technique: Tsuji\'s Needle"**.\n'
#  '  - **Haguro Hiroto**: A sorcerer known for his **"Cursed Technique: Cursed '
#  'Spirit"**.\n'
#  '\n'
#  '- **Key Themes**:\n'
#  '  - The **power and responsibility** of being a sorcerer.\n'
#  '  - The **cost of power** and the **burden of being a hero**.\n'
#  '  - **Love and loss**, especially in the case of **Satoru Gojo** and '
#  '**Megumi Fushiguro**.\n'
#  '\n'
#  '- **Plot Highlights**:\n'
#  '  - The **"Satoru Gojo" arc** where he faces his greatest challenge.\n'
#  '  - The **"Shinigami" arc** where he must fight against the **Shinigami**.\n'
#  '  - The **"Cursed Wands"** and **"Cursed Techniques"** that are central to '
#  'the story.\n'
#  '\n'
#  '---\n'
#  '\n'
#  'Would you like me to **clean up** the text or **summarize** it further?')
